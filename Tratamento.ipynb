# %%
import pandas as pd
import numpy as np

# %%
faltas = pd.read_excel('Faltas.xlsx')
prod = pd.read_excel('Produtividade.xlsx', skiprows=1)
espera = pd.read_excel("Tempo de Espera.xlsx", skiprows=1)

# %%
faltas
# Out:
#         UNIDADE Especialidades PROFISSIONAL  Total de Consultas  \
# 0         Total            NaN          NaN               38757
# 1    CLINICA JA          Total          NaN                8065
# 2    CLINICA JA  CLINICO GERAL          NaN                2382
# 3    CLINICA JA  CLINICO GERAL   MEDICO CDS                 201
# 4    CLINICA JA  CLINICO GERAL   MEDICO HPD                 683
# ..          ...            ...          ...                 ...
# 221  CLINICA DT      PEDIATRIA   MEDICO RAD                 173
# 222  CLINICA DT      PEDIATRIA   MEDICO SVR                 330
# 223  CLINICA DT      PEDIATRIA   MEDICO TDC                 323
# 224  CLINICA DT      PEDIATRIA   MEDICO VDS                 367
# 225         NaN            NaN          NaN               54872
#
#      Consultas Efetivadas  % Consultas Efetivadas  Consultas Canceladas  \
# 0                   22290                0.575122                 16467
# 1                    4382                0.543335                  3683
# 2                    1315                0.552057                  1067
# 3                     102                0.507463                    99
# 4                     404                0.591508                   279
# ..                    ...                     ...                   ...
# 221                    86                0.497110                    87
# 222                   215                0.651515                   115
# 223                   251                0.777090                    72
# 224                   266                0.724796                   101
# 225                 33138                0.603915                 21734
#
#      % Consultas Canceladas  Faltas Médicas  % Faltas Médicas  \
# 0                  0.424878            1086          0.028021
# 1                  0.456665             427          0.052945
# 2                  0.447943             109          0.045760
# 3                  0.492537               0          0.000000
# 4                  0.408492              30          0.043924
# ..                      ...             ...               ...
# 221                0.502890              44          0.254335
# 222                0.348485              17          0.051515
# 223                0.222910               0          0.000000
# 224                0.275204              29          0.079019
# 225                0.396085            1441          0.026261
#
#      Faltas Paciente  % Faltas Pacientes  Remarcações Médicas  \
# 0              13849            0.357329                 1015
# 1               2745            0.340360                  428
# 2                896            0.376154                   34
# 3                 73            0.363184                    0
# 4                249            0.364568                    0
# ..               ...                 ...                  ...
# 221               42            0.242775                    0
# 222               98            0.296970                    0
# 223               68            0.210526                    0
# 224               71            0.193460                    0
# 225            17917            0.326524                 1410
#
#      % Remarcações Médcas  Remarcações ADM  % Remarcações ADM  \
# 0                0.026189              517           0.013340
# 1                0.053069               83           0.010291
# 2                0.014274               28           0.011755
# 3                0.000000               26           0.129353
# 4                0.000000                0           0.000000
# ..                    ...              ...                ...
# 221              0.000000                1           0.005780
# 222              0.000000                0           0.000000
# 223              0.000000                4           0.012384
# 224              0.000000                1           0.002725
# 225              0.025696              966           0.017605
#
#      Remarcações Pacientes  % Remarcações Pacientes
# 0                    14912                 0.277800
# 1                     3467                 0.300616
# 2                      929                 0.280580
# 3                      105                 0.343137
# 4                      234                 0.255180
# ..                     ...                      ...
# 221                    106                 0.379928
# 222                    158                 0.323770
# 223                    161                 0.332645
# 224                    201                 0.353873
# 225                  22565                 0.291357
#
# [226 rows x 18 columns]

# %%
faltas_col = faltas[['UNIDADE', 'Especialidades', 'PROFISSIONAL','Consultas Efetivadas', 'Faltas Médicas', 'Faltas Paciente','Remarcações Médicas', 'Total de Consultas']]
faltas_col
# Out:
#         UNIDADE Especialidades PROFISSIONAL  Consultas Efetivadas  \
# 0         Total            NaN          NaN                 22290
# 1    CLINICA JA          Total          NaN                  4382
# 2    CLINICA JA  CLINICO GERAL          NaN                  1315
# 3    CLINICA JA  CLINICO GERAL   MEDICO CDS                   102
# 4    CLINICA JA  CLINICO GERAL   MEDICO HPD                   404
# ..          ...            ...          ...                   ...
# 221  CLINICA DT      PEDIATRIA   MEDICO RAD                    86
# 222  CLINICA DT      PEDIATRIA   MEDICO SVR                   215
# 223  CLINICA DT      PEDIATRIA   MEDICO TDC                   251
# 224  CLINICA DT      PEDIATRIA   MEDICO VDS                   266
# 225         NaN            NaN          NaN                 33138
#
#      Faltas Médicas  Faltas Paciente  Remarcações Médicas  Total de Consultas
# 0              1086            13849                 1015               38757
# 1               427             2745                  428                8065
# 2               109              896                   34                2382
# 3                 0               73                    0                 201
# 4                30              249                    0                 683
# ..              ...              ...                  ...                 ...
# 221              44               42                    0                 173
# 222              17               98                    0                 330
# 223               0               68                    0                 323
# 224              29               71                    0                 367
# 225            1441            17917                 1410               54872
#
# [226 rows x 8 columns]

# %%
faltas_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UNIDADE               224 non-null    object
#  1   Especialidades        223 non-null    object
#  2   PROFISSIONAL          176 non-null    object
#  3   Consultas Efetivadas  226 non-null    int64
#  4   Faltas Médicas        226 non-null    int64
#  5   Faltas Paciente       226 non-null    int64
#  6   Remarcações Médicas   226 non-null    int64
#  7   Total de Consultas    226 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 14.3+ KB

# %%
faltas_rename = {
    'UNIDADE': 'Unidade',
    'Especialidades' : 'Especialidade',
    'PROFISSIONAL' : 'Profissional'
}
faltas_clean = faltas_col.rename(columns = faltas_rename)
faltas_clean
# Out:
#         Unidade  Especialidade Profissional  Consultas Efetivadas  \
# 0         Total            NaN          NaN                 22290
# 1    CLINICA JA          Total          NaN                  4382
# 2    CLINICA JA  CLINICO GERAL          NaN                  1315
# 3    CLINICA JA  CLINICO GERAL   MEDICO CDS                   102
# 4    CLINICA JA  CLINICO GERAL   MEDICO HPD                   404
# ..          ...            ...          ...                   ...
# 221  CLINICA DT      PEDIATRIA   MEDICO RAD                    86
# 222  CLINICA DT      PEDIATRIA   MEDICO SVR                   215
# 223  CLINICA DT      PEDIATRIA   MEDICO TDC                   251
# 224  CLINICA DT      PEDIATRIA   MEDICO VDS                   266
# 225         NaN            NaN          NaN                 33138
#
#      Faltas Médicas  Faltas Paciente  Remarcações Médicas  Total de Consultas
# 0              1086            13849                 1015               38757
# 1               427             2745                  428                8065
# 2               109              896                   34                2382
# 3                 0               73                    0                 201
# 4                30              249                    0                 683
# ..              ...              ...                  ...                 ...
# 221              44               42                    0                 173
# 222              17               98                    0                 330
# 223               0               68                    0                 323
# 224              29               71                    0                 367
# 225            1441            17917                 1410               54872
#
# [226 rows x 8 columns]

# %%
faltas_clean = faltas_clean.dropna()
faltas_clean.isnull().sum()
# Out:
# Unidade                 0
# Especialidade           0
# Profissional            0
# Consultas Efetivadas    0
# Faltas Médicas          0
# Faltas Paciente         0
# Remarcações Médicas     0
# Total de Consultas      0
# dtype: int64

# %%
faltas_clean = faltas_clean.reset_index(drop=True)
faltas_clean
# Out:
#         Unidade                     Especialidade Profissional  \
# 0    CLINICA JA                     CLINICO GERAL   MEDICO CDS
# 1    CLINICA JA                     CLINICO GERAL   MEDICO HPD
# 2    CLINICA JA                     CLINICO GERAL   MEDICO JPS
# 3    CLINICA JA                     CLINICO GERAL   MEDICO TMP
# 4    CLINICA JA  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO BSG
# ..          ...                               ...          ...
# 171  CLINICA DT                         PEDIATRIA   MEDICO LFS
# 172  CLINICA DT                         PEDIATRIA   MEDICO RAD
# 173  CLINICA DT                         PEDIATRIA   MEDICO SVR
# 174  CLINICA DT                         PEDIATRIA   MEDICO TDC
# 175  CLINICA DT                         PEDIATRIA   MEDICO VDS
#
#      Consultas Efetivadas  Faltas Médicas  Faltas Paciente  \
# 0                     102               0               73
# 1                     404              30              249
# 2                     195               0              170
# 3                     614              79              404
# 4                     347              26              296
# ..                    ...             ...              ...
# 171                   274              51               90
# 172                    86              44               42
# 173                   215              17               98
# 174                   251               0               68
# 175                   266              29               71
#
#      Remarcações Médicas  Total de Consultas
# 0                      0                 201
# 1                      0                 683
# 2                      0                 365
# 3                     34                1133
# 4                     93                 763
# ..                   ...                 ...
# 171                   17                 444
# 172                    0                 173
# 173                    0                 330
# 174                    0                 323
# 175                    0                 367
#
# [176 rows x 8 columns]

# %%
faltas_clean['Especialidade'].unique()
# Out:
# array(['CLINICO GERAL', 'DERMATOLOGIA CLINICA E CIRURGICA', 'PEDIATRIA',
#        'ANESTESIOLOGIA', 'ANGIOLOGIA/CIRUR VASCULAR', 'CARDIOLOGIA',
#        'CIRURGIA GERAL', 'CIRURGIA ONCOLOGICA', 'CIRURGIA PEDIATRICA',
#        'GASTROENTEROLOGIA', 'GINECOLOGIA CLINICA', 'MASTOLOGIA',
#        'NEUROLOGIA', 'ONCOLOGIA CLINICA/QUIMIOTERAPIA',
#        'OTORRINOLARINGOLOGIA', 'PROCTOLOGIA', 'UROLOGIA',
#        'CIRURGIA GINECOLOGICA', 'CIRURGIA TORACICA', 'NEUROCIRURGIA',
#        'OBSTETRICIA / PRE NATAL', 'ONCOLOGIA PEDIATRICA',
#        'ORTOPEDIA E TRAUMATOLOGIA', 'CIRURGIA BUCO MAXILO FACIAL',
#        'CIRURGIA DE CABECA E PESCOCO'], dtype=object)

# %%
faltas_clean[faltas_clean.duplicated(subset = ['Unidade', 'Profissional'], keep = False)].sort_values(by = 'Profissional')
# Out:
#         Unidade                     Especialidade Profissional  \
# 151  CLINICA DT         ORTOPEDIA E TRAUMATOLOGIA   MEDICO AFL
# 123  CLINICA DT                     CLINICO GERAL   MEDICO AFL
# 83   CLINICA SL                     NEUROCIRURGIA   MEDICO DAF
# 88   CLINICA SL                        NEUROLOGIA   MEDICO DAF
# 89   CLINICA SL                        NEUROLOGIA   MEDICO JAP
# 84   CLINICA SL                     NEUROCIRURGIA   MEDICO JAP
# 92   CLINICA SL                        NEUROLOGIA   MEDICO MRF
# 85   CLINICA SL                     NEUROCIRURGIA   MEDICO MRF
# 98   CLINICA SL           OBSTETRICIA / PRE NATAL   MEDICO MVP
# 68   CLINICA SL             CIRURGIA GINECOLOGICA   MEDICO MVP
# 100  CLINICA SL           OBSTETRICIA / PRE NATAL   MEDICO RAC
# 80   CLINICA SL               GINECOLOGIA CLINICA   MEDICO RAC
# 86   CLINICA SL                     NEUROCIRURGIA   MEDICO TTS
# 94   CLINICA SL                        NEUROLOGIA   MEDICO TTS
# 133  CLINICA DT  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO WFA
# 132  CLINICA DT  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO WFA
# 87   CLINICA SL                     NEUROCIRURGIA   MEDICO WJS
# 95   CLINICA SL                        NEUROLOGIA   MEDICO WJS
#
#      Consultas Efetivadas  Faltas Médicas  Faltas Paciente  \
# 151                    63               0               21
# 123                   469               1              212
# 83                     39               8                7
# 88                     37              21               17
# 89                     73              31               38
# 84                     31               0               17
# 92                     69               0               49
# 85                     63               0               15
# 98                    122               0               17
# 68                    148               0               46
# 100                    23               0                5
# 80                     27               0               12
# 86                     63               0               30
# 94                     81               0               41
# 133                   106               1               21
# 132                     1               0                0
# 87                     29               0               11
# 95                     66               0               35
#
#      Remarcações Médicas  Total de Consultas
# 151                    0                  84
# 123                    8                 690
# 83                     0                  54
# 88                     0                  75
# 89                     0                 143
# 84                     0                  70
# 92                     0                 119
# 85                     0                  78
# 98                     0                 141
# 68                     0                 198
# 100                    0                  28
# 80                     0                  39
# 86                     0                  94
# 94                     0                 124
# 133                    0                 131
# 132                    0                  39
# 87                     0                  40
# 95                     0                 102

# %%
faltas_clean.loc[(faltas_clean['Especialidade'] == 'ORTOPEDIA E TRAUMATOLOGIA') & (faltas_clean['Profissional'] == 'MEDICO AFL'), 'Profissional'] = 'MEDICO AFLJ'

# %%
faltas_clean[faltas_clean.duplicated(subset = ['Unidade', 'Profissional'], keep = False)].sort_values(by = 'Profissional')
# Out:
#         Unidade                     Especialidade Profissional  \
# 83   CLINICA SL                     NEUROCIRURGIA   MEDICO DAF
# 88   CLINICA SL                        NEUROLOGIA   MEDICO DAF
# 84   CLINICA SL                     NEUROCIRURGIA   MEDICO JAP
# 89   CLINICA SL                        NEUROLOGIA   MEDICO JAP
# 85   CLINICA SL                     NEUROCIRURGIA   MEDICO MRF
# 92   CLINICA SL                        NEUROLOGIA   MEDICO MRF
# 68   CLINICA SL             CIRURGIA GINECOLOGICA   MEDICO MVP
# 98   CLINICA SL           OBSTETRICIA / PRE NATAL   MEDICO MVP
# 80   CLINICA SL               GINECOLOGIA CLINICA   MEDICO RAC
# 100  CLINICA SL           OBSTETRICIA / PRE NATAL   MEDICO RAC
# 86   CLINICA SL                     NEUROCIRURGIA   MEDICO TTS
# 94   CLINICA SL                        NEUROLOGIA   MEDICO TTS
# 132  CLINICA DT  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO WFA
# 133  CLINICA DT  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO WFA
# 87   CLINICA SL                     NEUROCIRURGIA   MEDICO WJS
# 95   CLINICA SL                        NEUROLOGIA   MEDICO WJS
#
#      Consultas Efetivadas  Faltas Médicas  Faltas Paciente  \
# 83                     39               8                7
# 88                     37              21               17
# 84                     31               0               17
# 89                     73              31               38
# 85                     63               0               15
# 92                     69               0               49
# 68                    148               0               46
# 98                    122               0               17
# 80                     27               0               12
# 100                    23               0                5
# 86                     63               0               30
# 94                     81               0               41
# 132                     1               0                0
# 133                   106               1               21
# 87                     29               0               11
# 95                     66               0               35
#
#      Remarcações Médicas  Total de Consultas
# 83                     0                  54
# 88                     0                  75
# 84                     0                  70
# 89                     0                 143
# 85                     0                  78
# 92                     0                 119
# 68                     0                 198
# 98                     0                 141
# 80                     0                  39
# 100                    0                  28
# 86                     0                  94
# 94                     0                 124
# 132                    0                  39
# 133                    0                 131
# 87                     0                  40
# 95                     0                 102

# %%
faltas_clean[faltas_clean.duplicated(subset = ['Unidade', 'Especialidade','Profissional'], keep = False)].sort_values(by ='Profissional')
# Out:
#         Unidade                     Especialidade Profissional  \
# 132  CLINICA DT  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO WFA
# 133  CLINICA DT  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO WFA
#
#      Consultas Efetivadas  Faltas Médicas  Faltas Paciente  \
# 132                     1               0                0
# 133                   106               1               21
#
#      Remarcações Médicas  Total de Consultas
# 132                    0                  39
# 133                    0                 131

# %%
faltas_clean = faltas_clean.groupby(['Unidade', 'Especialidade', 'Profissional'], as_index =False).sum()

# %%
faltas_clean[faltas_clean.duplicated(subset = ['Unidade', 'Especialidade','Profissional'], keep = False)].sort_values(by ='Profissional')
# Out:
# Empty DataFrame
# Columns: [Unidade, Especialidade, Profissional, Consultas Efetivadas, Faltas Médicas, Faltas Paciente, Remarcações Médicas, Total de Consultas]
# Index: []

# %%
# limpeza faltas_clean concluída
faltas_clean
# Out:
#         Unidade              Especialidade Profissional  Consultas Efetivadas  \
# 0    CLINICA DT  ANGIOLOGIA/CIRUR VASCULAR   MEDICO NJV                    42
# 1    CLINICA DT                CARDIOLOGIA   MEDICO AGH                    57
# 2    CLINICA DT                CARDIOLOGIA   MEDICO BGA                    76
# 3    CLINICA DT                CARDIOLOGIA   MEDICO FER                    71
# 4    CLINICA DT                CARDIOLOGIA   MEDICO FFD                    31
# ..          ...                        ...          ...                   ...
# 170  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO FCC                   157
# 171  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO JGS                   529
# 172  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO JHC                   529
# 173  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO MMB                   325
# 174  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO WAS                    41
#
#      Faltas Médicas  Faltas Paciente  Remarcações Médicas  Total de Consultas
# 0                 0               19                    0                  61
# 1                 0               19                    0                  76
# 2                11               42                    0                 129
# 3                 0               25                    0                  97
# 4                 0               17                    0                  65
# ..              ...              ...                  ...                 ...
# 170               1              101                   45                 307
# 171             102              331                   49                1018
# 172               0              291                   27                 860
# 173               0              211                    0                 544
# 174               0               26                    0                  67
#
# [175 rows x 8 columns]

# %%
prod
# Out:
#         UNIDADE ESPECIALIDADES      MEDICO  Qtd. Consultas  Qtd. Retorno  \
# 0           NaN            NaN         NaN           179.0          14.0
# 1         Total            NaN         NaN           179.0          14.0
# 2    CLINICA JA          Total         NaN             NaN           NaN
# 3    CLINICA JA  CLINICO GERAL         NaN             NaN           NaN
# 4    CLINICA JA  CLINICO GERAL  MEDICO CDS             NaN           NaN
# ..          ...            ...         ...             ...           ...
# 209  CLINICA DT      PEDIATRIA  MEDICO RAD             NaN           NaN
# 210  CLINICA DT      PEDIATRIA  MEDICO SVR             NaN           NaN
# 211  CLINICA DT      PEDIATRIA  MEDICO TDC             NaN           NaN
# 212  CLINICA DT      PEDIATRIA  MEDICO VDS             NaN           NaN
# 213         NaN            NaN         NaN           179.0          14.0
#
#      Atendimento Geral  Qtd. Horas  Produtividade  Meta  Qtd. Consultas.1  \
# 0                193.0   29.831667           6.47   5.5            1654.0
# 1                193.0   29.831667           6.47   5.5            1261.0
# 2                  NaN         NaN            NaN   NaN             321.0
# 3                  NaN         NaN            NaN   NaN             128.0
# 4                  NaN         NaN            NaN   NaN              36.0
# ..                 ...         ...            ...   ...               ...
# 209                NaN         NaN            NaN   NaN               NaN
# 210                NaN         NaN            NaN   NaN               NaN
# 211                NaN         NaN            NaN   NaN              27.0
# 212                NaN         NaN            NaN   NaN               NaN
# 213              193.0   29.831667           6.47   5.5            1654.0
#
#      ...  Atendimento Geral.24  Qtd. Horas.24  Produtividade.24  Meta.24  \
# 0    ...                  89.0         18.235              4.88      5.5
# 1    ...                   NaN            NaN               NaN      NaN
# 2    ...                   NaN            NaN               NaN      NaN
# 3    ...                   NaN            NaN               NaN      NaN
# 4    ...                   NaN            NaN               NaN      NaN
# ..   ...                   ...            ...               ...      ...
# 209  ...                   NaN            NaN               NaN      NaN
# 210  ...                   NaN            NaN               NaN      NaN
# 211  ...                   NaN            NaN               NaN      NaN
# 212  ...                   NaN            NaN               NaN      NaN
# 213  ...                  89.0         18.235              4.88      5.5
#
#      Qtd. Consultas.25  Qtd. Retorno.25  Atendimento Geral.25  Qtd. Horas.25  \
# 0                29619             3131                 32750    5617.094722
# 1                20136             1915                 22051    3621.978333
# 2                 3973              360                  4333     648.283611
# 3                 1138              177                  1315     134.781111
# 4                   98                4                   102      10.565278
# ..                 ...              ...                   ...            ...
# 209                 86                0                    86      15.692500
# 210                206                9                   215      55.434444
# 211                235               16                   251      50.071667
# 212                241               25                   266      57.236111
# 213              29619             3131                 32750    5617.094722
#
#      Produtividade.25  Meta.25
# 0                5.83      5.5
# 1                6.09      5.5
# 2                6.68      5.5
# 3                9.76      5.5
# 4                9.65      5.5
# ..                ...      ...
# 209              5.48      5.5
# 210              3.88      5.5
# 211              5.01      5.5
# 212              4.65      5.5
# 213              5.83      5.5
#
# [214 rows x 159 columns]

# %%
prod = prod[['UNIDADE', 'ESPECIALIDADES', 'MEDICO','Atendimento Geral.25','Qtd. Horas.25']]
prod
# Out:
#         UNIDADE ESPECIALIDADES      MEDICO  Atendimento Geral.25  \
# 0           NaN            NaN         NaN                 32750
# 1         Total            NaN         NaN                 22051
# 2    CLINICA JA          Total         NaN                  4333
# 3    CLINICA JA  CLINICO GERAL         NaN                  1315
# 4    CLINICA JA  CLINICO GERAL  MEDICO CDS                   102
# ..          ...            ...         ...                   ...
# 209  CLINICA DT      PEDIATRIA  MEDICO RAD                    86
# 210  CLINICA DT      PEDIATRIA  MEDICO SVR                   215
# 211  CLINICA DT      PEDIATRIA  MEDICO TDC                   251
# 212  CLINICA DT      PEDIATRIA  MEDICO VDS                   266
# 213         NaN            NaN         NaN                 32750
#
#      Qtd. Horas.25
# 0      5617.094722
# 1      3621.978333
# 2       648.283611
# 3       134.781111
# 4        10.565278
# ..             ...
# 209      15.692500
# 210      55.434444
# 211      50.071667
# 212      57.236111
# 213    5617.094722
#
# [214 rows x 5 columns]

# %%
prod = prod.rename(columns = {
    'UNIDADE': 'Unidade',
    'ESPECIALIDADES': 'Especialidade',
    'MEDICO': 'Profissional',
    'Atendimento Geral.25' : 'Atendimento Produtividade',
    'Qtd. Horas.25' : 'Quantidade Horas Produtividade'
})
prod
# Out:
#         Unidade  Especialidade Profissional  Atendimento Produtividade  \
# 0           NaN            NaN          NaN                      32750
# 1         Total            NaN          NaN                      22051
# 2    CLINICA JA          Total          NaN                       4333
# 3    CLINICA JA  CLINICO GERAL          NaN                       1315
# 4    CLINICA JA  CLINICO GERAL   MEDICO CDS                        102
# ..          ...            ...          ...                        ...
# 209  CLINICA DT      PEDIATRIA   MEDICO RAD                         86
# 210  CLINICA DT      PEDIATRIA   MEDICO SVR                        215
# 211  CLINICA DT      PEDIATRIA   MEDICO TDC                        251
# 212  CLINICA DT      PEDIATRIA   MEDICO VDS                        266
# 213         NaN            NaN          NaN                      32750
#
#      Quantidade Horas Produtividade
# 0                       5617.094722
# 1                       3621.978333
# 2                        648.283611
# 3                        134.781111
# 4                         10.565278
# ..                              ...
# 209                       15.692500
# 210                       55.434444
# 211                       50.071667
# 212                       57.236111
# 213                     5617.094722
#
# [214 rows x 5 columns]

# %%
prod_clean = prod.dropna()
prod_clean.isnull().sum()
# Out:
# Unidade                           0
# Especialidade                     0
# Profissional                      0
# Atendimento Produtividade         0
# Quantidade Horas Produtividade    0
# dtype: int64

# %%
prod_clean.loc[(prod_clean['Especialidade'] == 'ORTOPEDIA E TRAUMATOLOGIA') & (prod_clean['Profissional'] == 'MEDICO AFL'), 'Profissional'] = 'MEDICO AFLJ'
prod_clean.reset_index(drop=True)
# Out:
#         Unidade                     Especialidade Profissional  \
# 0    CLINICA JA                     CLINICO GERAL   MEDICO CDS
# 1    CLINICA JA                     CLINICO GERAL   MEDICO HPD
# 2    CLINICA JA                     CLINICO GERAL   MEDICO JPS
# 3    CLINICA JA                     CLINICO GERAL   MEDICO TMP
# 4    CLINICA JA  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO BSG
# ..          ...                               ...          ...
# 162  CLINICA DT                         PEDIATRIA   MEDICO LFS
# 163  CLINICA DT                         PEDIATRIA   MEDICO RAD
# 164  CLINICA DT                         PEDIATRIA   MEDICO SVR
# 165  CLINICA DT                         PEDIATRIA   MEDICO TDC
# 166  CLINICA DT                         PEDIATRIA   MEDICO VDS
#
#      Atendimento Produtividade  Quantidade Horas Produtividade
# 0                          102                       10.565278
# 1                          404                       35.775833
# 2                          195                       25.015833
# 3                          614                       63.424167
# 4                          346                       32.639722
# ..                         ...                             ...
# 162                        272                       81.645278
# 163                         86                       15.692500
# 164                        215                       55.434444
# 165                        251                       50.071667
# 166                        266                       57.236111
#
# [167 rows x 5 columns]

# %%
prod_clean['Especialidade'].unique()
# Out:
# array(['CLINICO GERAL', 'DERMATOLOGIA CLINICA E CIRURGICA', 'PEDIATRIA',
#        'ANESTESIOLOGIA', 'ANGIOLOGIA/CIRUR VASCULAR', 'CARDIOLOGIA',
#        'CIRURGIA GERAL', 'CIRURGIA PEDIATRICA', 'GASTROENTEROLOGIA',
#        'GINECOLOGIA CLINICA', 'MASTOLOGIA', 'NEUROLOGIA',
#        'OTORRINOLARINGOLOGIA', 'PROCTOLOGIA', 'UROLOGIA',
#        'CIRURGIA GINECOLOGICA', 'NEUROCIRURGIA',
#        'OBSTETRICIA / PRE NATAL', 'ORTOPEDIA E TRAUMATOLOGIA',
#        'CIRURGIA BUCO MAXILO FACIAL', 'CIRURGIA DE CABECA E PESCOCO',
#        'CIRURGIA TORACICA'], dtype=object)

# %%
prod_clean[prod_clean.duplicated(subset=['Unidade','Profissional'], keep=False)].sort_values(by = 'Profissional')
# Out:
#         Unidade            Especialidade Profissional  \
# 106  CLINICA SL            NEUROCIRURGIA   MEDICO DAF
# 112  CLINICA SL               NEUROLOGIA   MEDICO DAF
# 107  CLINICA SL            NEUROCIRURGIA   MEDICO JAP
# 113  CLINICA SL               NEUROLOGIA   MEDICO JAP
# 108  CLINICA SL            NEUROCIRURGIA   MEDICO MRF
# 116  CLINICA SL               NEUROLOGIA   MEDICO MRF
# 88   CLINICA SL    CIRURGIA GINECOLOGICA   MEDICO MVP
# 123  CLINICA SL  OBSTETRICIA / PRE NATAL   MEDICO MVP
# 102  CLINICA SL      GINECOLOGIA CLINICA   MEDICO RAC
# 125  CLINICA SL  OBSTETRICIA / PRE NATAL   MEDICO RAC
# 109  CLINICA SL            NEUROCIRURGIA   MEDICO TTS
# 118  CLINICA SL               NEUROLOGIA   MEDICO TTS
# 110  CLINICA SL            NEUROCIRURGIA   MEDICO WJS
# 119  CLINICA SL               NEUROLOGIA   MEDICO WJS
#
#      Atendimento Produtividade  Quantidade Horas Produtividade
# 106                         39                        3.169722
# 112                         37                        6.821111
# 107                         31                        3.958889
# 113                         73                        8.685000
# 108                         63                        5.450278
# 116                         69                        6.539722
# 88                         148                       28.678889
# 123                        122                       20.226389
# 102                         27                        0.000000
# 125                         23                        8.311667
# 109                         63                        7.404722
# 118                         81                       11.211667
# 110                         29                        0.000000
# 119                         66                       10.533611

# %%
prod_clean[prod_clean.duplicated(subset = ['Unidade', 'Especialidade','Profissional'], keep = False)].sort_values(by ='Profissional')
# Out:
# Empty DataFrame
# Columns: [Unidade, Especialidade, Profissional, Atendimento Produtividade, Quantidade Horas Produtividade]
# Index: []

# %%
# Out:
#         Unidade                     Especialidade Profissional  \
# 4    CLINICA JA                     CLINICO GERAL   MEDICO CDS
# 5    CLINICA JA                     CLINICO GERAL   MEDICO HPD
# 6    CLINICA JA                     CLINICO GERAL   MEDICO JPS
# 7    CLINICA JA                     CLINICO GERAL   MEDICO TMP
# 9    CLINICA JA  DERMATOLOGIA CLINICA E CIRURGICA   MEDICO BSG
# ..          ...                               ...          ...
# 208  CLINICA DT                         PEDIATRIA   MEDICO LFS
# 209  CLINICA DT                         PEDIATRIA   MEDICO RAD
# 210  CLINICA DT                         PEDIATRIA   MEDICO SVR
# 211  CLINICA DT                         PEDIATRIA   MEDICO TDC
# 212  CLINICA DT                         PEDIATRIA   MEDICO VDS
#
#      Atendimento Produtividade  Quantidade Horas Produtividade
# 4                          102                       10.565278
# 5                          404                       35.775833
# 6                          195                       25.015833
# 7                          614                       63.424167
# 9                          346                       32.639722
# ..                         ...                             ...
# 208                        272                       81.645278
# 209                         86                       15.692500
# 210                        215                       55.434444
# 211                        251                       50.071667
# 212                        266                       57.236111
#
# [167 rows x 5 columns]

# %%
#prod_clean finalizado

# %%
espera
# Out:
#         Unidade   Especialidade      Médico  % PCTE > 30 MIN  QTDE PCTE > 30  \
# 0         Total             NaN         NaN         0.405882            69.0
# 1    CLINICA JA           Total         NaN              NaN             NaN
# 2    CLINICA JA  CLINICA MÉDICA         NaN              NaN             NaN
# 3    CLINICA JA  CLINICA MÉDICA         NaN              NaN             NaN
# 4    CLINICA JA  CLINICA MÉDICA  MEDICO AKM              NaN             NaN
# ..          ...             ...         ...              ...             ...
# 422  CLINICA DT       PEDIATRIA  MEDICO SMM              NaN             NaN
# 423  CLINICA DT       PEDIATRIA  MEDICO SVR              NaN             NaN
# 424  CLINICA DT       PEDIATRIA  MEDICO TDC              NaN             NaN
# 425  CLINICA DT       PEDIATRIA  MEDICO VDS              NaN             NaN
# 426         NaN             NaN         NaN         0.405882            69.0
#
#      QTDE USUARIOS  % PCTE > 30 MIN.1  QTDE PCTE > 30.1  QTDE USUARIOS.1  \
# 0            170.0           0.357973             431.0           1204.0
# 1              NaN           0.448680             153.0            341.0
# 2              NaN           0.100000              14.0            140.0
# 3              NaN           0.000000               0.0              1.0
# 4              NaN                NaN               NaN              NaN
# ..             ...                ...               ...              ...
# 422            NaN                NaN               NaN              NaN
# 423            NaN                NaN               NaN              NaN
# 424            NaN           0.531250              17.0             32.0
# 425            NaN                NaN               NaN              NaN
# 426          170.0           0.320721             534.0           1665.0
#
#      % PCTE > 30 MIN.2  ...  QTDE USUARIOS.22  % PCTE > 30 MIN.23  \
# 0             0.342105  ...             898.0            0.287690
# 1             0.456522  ...              95.0            0.392857
# 2             0.050000  ...               6.0            0.000000
# 3                  NaN  ...               1.0            0.000000
# 4                  NaN  ...               NaN                 NaN
# ..                 ...  ...               ...                 ...
# 422                NaN  ...               NaN                 NaN
# 423           0.640000  ...               NaN                 NaN
# 424                NaN  ...              34.0                 NaN
# 425                NaN  ...              28.0            0.428571
# 426           0.336182  ...            1549.0            0.328583
#
#      QTDE PCTE > 30.23  QTDE USUARIOS.23  % PCTE > 30 MIN.24  \
# 0                208.0             723.0                 NaN
# 1                 55.0             140.0                 NaN
# 2                  0.0              45.0                 NaN
# 3                  0.0               2.0                 NaN
# 4                  NaN               NaN                 NaN
# ..                 ...               ...                 ...
# 422                NaN               NaN                 NaN
# 423                NaN               NaN                 NaN
# 424                NaN               NaN                 NaN
# 425               15.0              35.0                 NaN
# 426              415.0            1263.0            0.564103
#
#      QTDE PCTE > 30.24  QTDE USUARIOS.24  % PCTE > 30 MIN.25  \
# 0                  NaN               NaN            0.336687
# 1                  NaN               NaN            0.366461
# 2                  NaN               NaN            0.057735
# 3                  NaN               NaN            0.000000
# 4                  NaN               NaN            0.500000
# ..                 ...               ...                 ...
# 422                NaN               NaN            0.000000
# 423                NaN               NaN            0.737089
# 424                NaN               NaN            0.598394
# 425                NaN               NaN            0.319549
# 426               66.0             117.0            0.347708
#
#      QTDE PCTE > 30.25  QTDE USUARIOS.25
# 0                 6626             19680
# 1                 1604              4377
# 2                   78              1351
# 3                    0                25
# 4                    2                 4
# ..                 ...               ...
# 422                  0                 1
# 423                157               213
# 424                149               249
# 425                 85               266
# 426              10764             30957
#
# [427 rows x 81 columns]

# %%
espera_clean = espera[['Unidade', 'Especialidade', 'Médico', 'QTDE USUARIOS.25', 'QTDE PCTE > 30.25']]
espera_clean
# Out:
#         Unidade   Especialidade      Médico  QTDE USUARIOS.25  \
# 0         Total             NaN         NaN             19680
# 1    CLINICA JA           Total         NaN              4377
# 2    CLINICA JA  CLINICA MÉDICA         NaN              1351
# 3    CLINICA JA  CLINICA MÉDICA         NaN                25
# 4    CLINICA JA  CLINICA MÉDICA  MEDICO AKM                 4
# ..          ...             ...         ...               ...
# 422  CLINICA DT       PEDIATRIA  MEDICO SMM                 1
# 423  CLINICA DT       PEDIATRIA  MEDICO SVR               213
# 424  CLINICA DT       PEDIATRIA  MEDICO TDC               249
# 425  CLINICA DT       PEDIATRIA  MEDICO VDS               266
# 426         NaN             NaN         NaN             30957
#
#      QTDE PCTE > 30.25
# 0                 6626
# 1                 1604
# 2                   78
# 3                    0
# 4                    2
# ..                 ...
# 422                  0
# 423                157
# 424                149
# 425                 85
# 426              10764
#
# [427 rows x 5 columns]

# %%
espera_clean = espera_clean.rename(columns = {
    'Médico': 'Profissional',
    'QTDE USUARIOS.25': 'Usuários',
    'QTDE PCTE > 30.25': 'Espera > 30'
    })
espera_clean
# Out:
#         Unidade   Especialidade Profissional  Usuários  Espera > 30
# 0         Total             NaN          NaN     19680         6626
# 1    CLINICA JA           Total          NaN      4377         1604
# 2    CLINICA JA  CLINICA MÉDICA          NaN      1351           78
# 3    CLINICA JA  CLINICA MÉDICA          NaN        25            0
# 4    CLINICA JA  CLINICA MÉDICA   MEDICO AKM         4            2
# ..          ...             ...          ...       ...          ...
# 422  CLINICA DT       PEDIATRIA   MEDICO SMM         1            0
# 423  CLINICA DT       PEDIATRIA   MEDICO SVR       213          157
# 424  CLINICA DT       PEDIATRIA   MEDICO TDC       249          149
# 425  CLINICA DT       PEDIATRIA   MEDICO VDS       266           85
# 426         NaN             NaN          NaN     30957        10764
#
# [427 rows x 5 columns]

# %%
espera_clean = espera_clean.dropna()
espera_clean.isnull().sum()
# Out:
# Unidade          0
# Especialidade    0
# Profissional     0
# Usuários         0
# Espera > 30      0
# dtype: int64

# %%
espera_clean.loc[(espera_clean['Especialidade'] == 'ORTOPEDIA E TRAUMATOLOGIA') & (espera_clean['Profissional'] == 'MEDICO AFL'), 'Profissional'] = 'MEDICO AFLJ'

# %%
espera_clean[espera_clean.duplicated(subset=['Unidade','Profissional'], keep=False)].sort_values(by = 'Profissional')
# Out:
#         Unidade                     Especialidade Profissional  Usuários  \
# 328  CLINICA DT               GINECOLOGIA CLÍNICA   MEDICO ACD         1
# 411  CLINICA DT                         PEDIATRIA   MEDICO ACD       451
# 297  CLINICA DT                    CLÍNICA MÉDICA   MEDICO AFL       463
# 412  CLINICA DT                         PEDIATRIA   MEDICO AFL         2
# 4    CLINICA JA                    CLINICA MÉDICA   MEDICO AKM         4
# ..          ...                               ...          ...       ...
# 425  CLINICA DT                         PEDIATRIA   MEDICO VDS       266
# 324  CLINICA DT  DERMATOLOGIA CLÍNICA E CIRÚRGICA   MEDICO WFA       106
# 323  CLINICA DT  DERMATOLOGIA CLÍNICA E CIRÚRGICA   MEDICO WFA        15
# 246  CLINICA SL                        NEUROLOGIA   MEDICO WJS        45
# 234  CLINICA SL                     NEUROCIRURGIA   MEDICO WJS        34
#
#      Espera > 30
# 328            1
# 411          382
# 297           27
# 412            0
# 4              2
# ..           ...
# 425           85
# 324            1
# 323            0
# 246           32
# 234           26
#
# [300 rows x 5 columns]

# %%
espera_clean.groupby(['Unidade', 'Profissional'], as_index =False).sum()
# Out:
#         Unidade Profissional                                   Especialidade  \
# 0    CLINICA DT   MEDICO AAV                             GINECOLOGIA CLÍNICA
# 1    CLINICA DT   MEDICO ACD                    GINECOLOGIA CLÍNICAPEDIATRIA
# 2    CLINICA DT   MEDICO ADC                             GINECOLOGIA CLÍNICA
# 3    CLINICA DT   MEDICO AFL                         CLÍNICA MÉDICAPEDIATRIA
# 4    CLINICA DT  MEDICO AFLJ                       ORTOPEDIA E TRAUMATOLOGIA
# ..          ...          ...                                             ...
# 161  CLINICA SL   MEDICO TDO                       CLINICA MEDICAGINECOLOGIA
# 162  CLINICA SL   MEDICO TMP                                  CLINICA MEDICA
# 163  CLINICA SL   MEDICO TTS  CLINICA MEDICANEUROCIRURGIANEUROLOGIAORTOPEDIA
# 164  CLINICA SL   MEDICO WAS                                       ORTOPEDIA
# 165  CLINICA SL   MEDICO WJS                         NEUROCIRURGIANEUROLOGIA
#
#      Usuários  Espera > 30
# 0         114           32
# 1         452          383
# 2          91           69
# 3         465           27
# 4          63           18
# ..        ...          ...
# 161       183           14
# 162       221           58
# 163       119           19
# 164        37           17
# 165        79           58
#
# [166 rows x 5 columns]

# %%
espera_sem_dupli = espera_clean.groupby(['Unidade', 'Profissional'], as_index =False).sum()

# %%
espera_sem_dupli[espera_sem_dupli.duplicated(subset=['Unidade','Profissional'], keep=False)].sort_values(by = 'Profissional')
# Out:
# Empty DataFrame
# Columns: [Unidade, Profissional, Especialidade, Usuários, Espera > 30]
# Index: []

# %%
espera_clean = espera_sem_dupli.drop(columns = ['Especialidade']).reset_index(drop = True)
espera_clean
# Out:
#         Unidade Profissional  Usuários  Espera > 30
# 0    CLINICA DT   MEDICO AAV       114           32
# 1    CLINICA DT   MEDICO ACD       452          383
# 2    CLINICA DT   MEDICO ADC        91           69
# 3    CLINICA DT   MEDICO AFL       465           27
# 4    CLINICA DT  MEDICO AFLJ        63           18
# ..          ...          ...       ...          ...
# 161  CLINICA SL   MEDICO TDO       183           14
# 162  CLINICA SL   MEDICO TMP       221           58
# 163  CLINICA SL   MEDICO TTS       119           19
# 164  CLINICA SL   MEDICO WAS        37           17
# 165  CLINICA SL   MEDICO WJS        79           58
#
# [166 rows x 4 columns]

# %%
df_merge = pd.merge(faltas_clean, prod_clean, on =['Unidade', 'Profissional', 'Especialidade'], how= 'outer')
df_merge = pd.merge(df_merge, espera_clean, on= ['Unidade', 'Profissional'], how = 'outer')
df_merge
# Out:
#         Unidade              Especialidade Profissional  Consultas Efetivadas  \
# 0    CLINICA DT  ANGIOLOGIA/CIRUR VASCULAR   MEDICO NJV                  42.0
# 1    CLINICA DT                CARDIOLOGIA   MEDICO AGH                  57.0
# 2    CLINICA DT                CARDIOLOGIA   MEDICO BGA                  76.0
# 3    CLINICA DT                CARDIOLOGIA   MEDICO FER                  71.0
# 4    CLINICA DT                CARDIOLOGIA   MEDICO FFD                  31.0
# ..          ...                        ...          ...                   ...
# 173  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO MMB                 325.0
# 174  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO WAS                  41.0
# 175  CLINICA JA                        NaN   MEDICO DAD                   NaN
# 176  CLINICA LV                        NaN   MEDICO MCM                   NaN
# 177  CLINICA SL                        NaN   MEDICO JPL                   NaN
#
#      Faltas Médicas  Faltas Paciente  Remarcações Médicas  Total de Consultas  \
# 0               0.0             19.0                  0.0                61.0
# 1               0.0             19.0                  0.0                76.0
# 2              11.0             42.0                  0.0               129.0
# 3               0.0             25.0                  0.0                97.0
# 4               0.0             17.0                  0.0                65.0
# ..              ...              ...                  ...                 ...
# 173             0.0            211.0                  0.0               544.0
# 174             0.0             26.0                  0.0                67.0
# 175             NaN              NaN                  NaN                 NaN
# 176             NaN              NaN                  NaN                 NaN
# 177             NaN              NaN                  NaN                 NaN
#
#      Atendimento Produtividade  Quantidade Horas Produtividade  Usuários  \
# 0                         42.0                        4.250000      43.0
# 1                         57.0                        9.392500      57.0
# 2                         76.0                        8.108333      79.0
# 3                         71.0                        9.903611      71.0
# 4                         22.0                        1.809167      31.0
# ..                         ...                             ...       ...
# 173                      325.0                       61.434167     291.0
# 174                       41.0                       10.063889      37.0
# 175                        NaN                             NaN       1.0
# 176                        NaN                             NaN       1.0
# 177                        NaN                             NaN       1.0
#
#      Espera > 30
# 0           25.0
# 1            9.0
# 2            2.0
# 3           13.0
# 4           30.0
# ..           ...
# 173          0.0
# 174         17.0
# 175          0.0
# 176          0.0
# 177          0.0
#
# [178 rows x 12 columns]

# %%
df_merge.dropna(subset = ['Especialidade'], inplace = True)
df_merge
# Out:
#         Unidade              Especialidade Profissional  Consultas Efetivadas  \
# 0    CLINICA DT  ANGIOLOGIA/CIRUR VASCULAR   MEDICO NJV                  42.0
# 1    CLINICA DT                CARDIOLOGIA   MEDICO AGH                  57.0
# 2    CLINICA DT                CARDIOLOGIA   MEDICO BGA                  76.0
# 3    CLINICA DT                CARDIOLOGIA   MEDICO FER                  71.0
# 4    CLINICA DT                CARDIOLOGIA   MEDICO FFD                  31.0
# ..          ...                        ...          ...                   ...
# 170  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO FCC                 157.0
# 171  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO JGS                 529.0
# 172  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO JHC                 529.0
# 173  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO MMB                 325.0
# 174  CLINICA SL  ORTOPEDIA E TRAUMATOLOGIA   MEDICO WAS                  41.0
#
#      Faltas Médicas  Faltas Paciente  Remarcações Médicas  Total de Consultas  \
# 0               0.0             19.0                  0.0                61.0
# 1               0.0             19.0                  0.0                76.0
# 2              11.0             42.0                  0.0               129.0
# 3               0.0             25.0                  0.0                97.0
# 4               0.0             17.0                  0.0                65.0
# ..              ...              ...                  ...                 ...
# 170             1.0            101.0                 45.0               307.0
# 171           102.0            331.0                 49.0              1018.0
# 172             0.0            291.0                 27.0               860.0
# 173             0.0            211.0                  0.0               544.0
# 174             0.0             26.0                  0.0                67.0
#
#      Atendimento Produtividade  Quantidade Horas Produtividade  Usuários  \
# 0                         42.0                        4.250000      43.0
# 1                         57.0                        9.392500      57.0
# 2                         76.0                        8.108333      79.0
# 3                         71.0                        9.903611      71.0
# 4                         22.0                        1.809167      31.0
# ..                         ...                             ...       ...
# 170                      157.0                       25.308056     145.0
# 171                      529.0                      106.409444     492.0
# 172                      529.0                       86.376389     476.0
# 173                      325.0                       61.434167     291.0
# 174                       41.0                       10.063889      37.0
#
#      Espera > 30
# 0           25.0
# 1            9.0
# 2            2.0
# 3           13.0
# 4           30.0
# ..           ...
# 170         62.0
# 171          8.0
# 172         61.0
# 173          0.0
# 174         17.0
#
# [175 rows x 12 columns]

# %%
df_merge = df_merge.fillna(0).reset_index(drop = True)

# %%
df_merge.to_excel('df_anon.xlsx', index = False)
